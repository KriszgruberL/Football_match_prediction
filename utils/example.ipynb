# %%
import pandas as pd
df = pd.read_csv('/Users/alexjones/Desktop/CSV_SQL/Football_match_prediction/processing/dataset.csv')

# %%
df.head()
# Out:
#   Div        Date      Time             HomeTeam       AwayTeam  FTHG  FTAG  \
# 0  B1  2024-09-01  18:15:00             Kortrijk     St Truiden   1.0   1.0
# 1  B1  2024-09-01  17:30:00         St. Gilloise     Anderlecht   0.0   0.0
# 2  B1  2024-09-01  15:00:00                 Gent        Antwerp   1.0   1.0
# 3  B1  2024-09-01  12:30:00          Club Brugge  Cercle Brugge   3.0   0.0
# 4  B1  2024-08-31  19:45:00  Oud-Heverlee Leuven       Standard   2.0   0.0
#
#   FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 0   D   0.0   1.0  ...     1.84 -0.25      1.75      2.05   1.79   2.11
# 1   D   0.0   0.0  ...     1.98 -0.50      1.93      1.93   1.94   1.94
# 2   D   1.0   1.0  ...     2.13  0.00      1.80      2.05   1.85   2.05
# 3   H   2.0   0.0  ...     2.58 -1.00      1.90      1.95   1.93   1.96
# 4   H   1.0   0.0  ...     1.80 -0.50      1.98      1.88   1.96   1.93
#
#    MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
df.groupby(df['HomeTeam'] == 'Kortrijk')['FTHG'].mean()
# Out:
# HomeTeam
# False    1.617875
# True     1.218391
# Name: FTHG, dtype: float64

# %%
list_teams = df['HomeTeam'].tolist()

# %%
for x in list_teams:
    print(x, df.groupby(df['HomeTeam'] == x)['FTHG'].mean())
# Out:
# Kortrijk HomeTeam
# False    1.617875
# True     1.218391
# Name: FTHG, dtype: float64
# St. Gilloise HomeTeam
# False    1.580289
# True     1.964912
# Name: FTHG, dtype: float64
# Gent HomeTeam
# False    1.564482
# True     2.078652
# Name: FTHG, dtype: float64
# Club Brugge HomeTeam
# False    1.557435
# True     2.191011
# Name: FTHG, dtype: float64
# Oud-Heverlee Leuven HomeTeam
# False    1.599024
# True     1.513514
# Name: FTHG, dtype: float64
# Beerschot VA HomeTeam
# False    1.599592
# True     1.405405
# Name: FTHG, dtype: float64
# Mechelen HomeTeam
# False    1.580691
# True     1.820225
# Name: FTHG, dtype: float64
# Genk HomeTeam
# False    1.568710
# True     2.011236
# Name: FTHG, dtype: float64
# Charleroi HomeTeam
# False    1.609001
# True     1.360465
# Name: FTHG, dtype: float64
# Standard HomeTeam
# False    1.608451
# True     1.375000
# Name: FTHG, dtype: float64
# St Truiden HomeTeam
# False    1.614085
# True     1.284091
# Name: FTHG, dtype: float64
# ...
